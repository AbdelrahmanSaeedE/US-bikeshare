# %%
import pandas as pd
import numpy as np
import datetime as dt

data = pd.read_csv('chicago.csv')
del data['Unnamed: 0']
data['Start Time'] = pd.to_datetime(data['Start Time'])
data['month'] = data['Start Time'].dt.month
data['day_of_week'] = data['Start Time'].dt.day_name()
month = 'all'
day = 'all'
if month != 'all':
    months = ['january', 'february', 'march', 'april', 'may', 'june']
    month = months.index(month) + 1
    data = data[data['month'] == month]

    
if day != 'all':
    data = data[data['day_of_week'] == day.title()]

data.head(50)
# Out:
#             Start Time             End Time  Trip Duration  \
# 0  2017-06-23 15:09:32  2017-06-23 15:14:53            321
# 1  2017-05-25 18:19:03  2017-05-25 18:45:53           1610
# 2  2017-01-04 08:27:49  2017-01-04 08:34:45            416
# 3  2017-03-06 13:49:38  2017-03-06 13:55:28            350
# 4  2017-01-17 14:53:07  2017-01-17 15:02:01            534
# 5  2017-06-26 09:01:20  2017-06-26 09:11:06            586
# 6  2017-05-26 09:41:44  2017-05-26 09:46:25            281
# 7  2017-01-21 14:28:38  2017-01-21 14:40:41            723
# 8  2017-04-20 16:08:51  2017-04-20 16:20:20            689
# 9  2017-02-06 18:00:47  2017-02-06 18:09:00            493
# 10 2017-02-15 07:09:55  2017-02-15 07:14:56            301
# 11 2017-01-22 15:15:45  2017-01-22 15:31:02            917
# 12 2017-01-08 16:03:00  2017-01-08 16:07:37            277
# 13 2017-05-30 15:46:18  2017-05-30 15:52:12            354
# 14 2017-04-20 19:26:33  2017-04-20 19:35:08            515
# ...

# %%
data.tail()
# Out:
#                 Start Time             End Time  Trip Duration  \
# 299995 2017-04-26 03:12:14  2017-04-26 03:41:19       1745.528
# 299996 2017-06-11 09:48:52  2017-06-11 10:22:31       2018.450
# 299997 2017-01-04 14:33:00  2017-01-04 14:43:00        583.897
# 299998 2017-04-28 07:17:47  2017-04-28 07:56:31       2324.170
# 299999 2017-06-16 04:08:16  2017-06-16 04:29:38       1281.459
#
#                            Start Station  \
# 299995                  Lincoln Memorial
# 299996             Key Blvd & N Quinn St
# 299997  17th & K St NW / Farragut Square
# 299998         Jefferson Dr & 14th St SW
# 299999               10th & Monroe St NE
#
#                                  End Station   User Type  month day_of_week
# 299995             Jefferson Dr & 14th St SW    Customer      4   Wednesday
# 299996                         5th & K St NW  Subscriber      6      Sunday
# 299997        7th & F St NW/Portrait Gallery  Subscriber      1   Wednesday
# ...

# %%
user_types = data1['Gender'].value_counts()
user_types1 = data['Gender'].value_counts()

# %%
print(user_types)
print(user_types1)
# Out:
# Male      2390
# Female     508
# Name: Gender, dtype: int64
# Male      181190
# Female     57758
# Name: Gender, dtype: int64

# %%
months = ['january', 'february', 'march', 'april', 'may', 'june']
mostcommonm = data['month'].mode()[0]
print('Most Common Month : {}'.format(months[mostcommonm-1]))
mostcommond = data['day_of_week'].mode()[0]
print('Most Common Day : {}'.format(mostcommond))
data['hour'] = data['Start Time'].dt.hour
# display the most common start hour
mostcommonh = data['hour'].mode()[0]
print('Most Common Hour : {}'.format(mostcommonh))
# Out:
# Most Common Month : june
# Most Common Day : Tuesday
# Most Common Hour : 17

# %%
mostcommont= data['Start Station'].mode()[0]
print('Most Common Start Station : {}'.format(mostcommont))
mostcommonte= data['End Station'].mode()[0]
print('Most Common End Station : {}'.format(mostcommonte))

data['Trip'] = "From (" + data['Start Station'] + ") To (" + data['End Station'] + ")"
mostcommontt= data['Trip'].mode()[0]
print('Most Common Trip : {}'.format(mostcommontt))
# Out:
# Most Common Start Station : Columbus Circle / Union Station
# Most Common End Station : Columbus Circle / Union Station
# Most Common Trip : From (Jefferson Dr & 14th St SW) To (Jefferson Dr & 14th St SW)
#             Start Time             End Time  Trip Duration  \
# 0  2017-06-21 08:36:34  2017-06-21 08:44:43        489.066
# 1  2017-03-11 10:40:00  2017-03-11 10:46:00        402.549
# 2  2017-05-30 01:02:59  2017-05-30 01:13:37        637.251
# 3  2017-04-02 07:48:35  2017-04-02 08:19:03       1827.341
# 4  2017-06-10 08:36:28  2017-06-10 09:02:17       1549.427
# 5  2017-05-14 07:18:18  2017-05-14 07:24:56        398.000
# 6  2017-06-19 08:41:43  2017-06-19 09:00:08       1105.429
# 7  2017-06-20 05:54:42  2017-06-20 06:05:18        636.218
# 8  2017-03-24 20:37:00  2017-03-24 20:42:00        328.530
# 9  2017-02-20 21:12:00  2017-02-20 21:31:00       1188.090
# 10 2017-04-17 02:50:51  2017-04-17 03:05:17        866.689
# ...

# %%
total_time = data['Trip Duration'].mean()
print(total_time)
# Out:
# 936.23929

# %%
oldest = int(data['Birth Year'].min()) 
youngest = int(data['Birth Year'].max())
most_year = int(data['Birth Year'].mode()[0])
print('(earliest) (most recent) (most common) year of birth \n  {}        {}          {}\n'.format(oldest,youngest,most_year))
# Out:
# (earliest) (most recent) (most common) year of birth
#   1899        2016          1989

# %%
data[5:10]
# Out:
#            Start Time             End Time  Trip Duration  \
# 5 2017-06-26 09:01:20  2017-06-26 09:11:06            586
# 6 2017-05-26 09:41:44  2017-05-26 09:46:25            281
# 7 2017-01-21 14:28:38  2017-01-21 14:40:41            723
# 8 2017-04-20 16:08:51  2017-04-20 16:20:20            689
# 9 2017-02-06 18:00:47  2017-02-06 18:09:00            493
#
#                   Start Station                    End Station   User Type  \
# 5  Clinton St & Washington Blvd           Canal St & Taylor St  Subscriber
# 6         Ashland Ave & Lake St           Wood St & Hubbard St  Subscriber
# 7    Larrabee St & Kingsbury St     Larrabee St & Armitage Ave    Customer
# 8        Sedgwick St & Huron St  Halsted St & Blackhawk St (*)  Subscriber
# 9  Stetson Ave & South Water St   Clinton St & Washington Blvd  Subscriber
#
#    Gender  Birth Year  month day_of_week  hour
# 5    Male      1990.0      6      Monday     9
# 6  Female      1983.0      5      Friday     9
# ...
